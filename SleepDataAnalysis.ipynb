# %% [markdown]
# The model achieves an accuracy of 87% with an average F1 score of 0.83, indicating it performs fairly well in predicting sleep disorders.

# %% [markdown]
# ### Random Forest Classifier

# %%
# initialize RandomForectClassifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# training the model with train dataset
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Visualize how well model's predictions match actual values

rf_pred = rfc.predict(X_test)
plt.figure(figsize=(10,6))

# Plot actual values with kde
sns.histplot(y_test, color="r", kde=True, label="Actual Value", stat="density", common_norm=False)

# Plot predicted values with kde
sns.histplot(rf_pred, color="b", kde=True, label="Predicted Values", stat="density", common_norm=False)

# Add title and labels
plt.title('Actual vs Predicted Distributions for Sleep Disorder Prediction')
plt.xlabel('Sleep Disorder')
plt.ylabel('Proportion of People')

# Show the legend
plt.legend()
plt.show()
